# %% [markdown]
# <a href="https://colab.research.google.com/github/akbarovyodgorbek931-hue/Yodgor1/blob/main/pandas_3_ipynd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-734ba1b0-be7c-455f-95e7-b7ab90c33a76" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-734ba1b0-be7c-455f-95e7-b7ab90c33a76">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv("pandas_homework_dirty_data_2150_rows.csv")
df.head()
# Out:
#    order_id    shop  product     city amount   shop_date
# 0         1  Shop B   Laptop  Bukhara   3950  16.01.2025
# 1         2  Shop E   Laptop      NaN   1393         NaN
# 2         3     NaN  Monitor      NaN  1,200  17.09.2025
# 3         4     NaN      NaN  Bukhara   2456  21.01.2025
# 4         5     NaN   Laptop      NaN   4715  14.01.2025

# %%
df["shop"] = df["shop"].fillna("magazin")

# %%
df.head()
# Out:
#    order_id     shop  product     city amount   shop_date
# 0         1   Shop B   Laptop  Bukhara   3950  16.01.2025
# 1         2   Shop E   Laptop      NaN   1393         NaN
# 2         3  magazin  Monitor      NaN  1,200  17.09.2025
# 3         4  magazin      NaN  Bukhara   2456  21.01.2025
# 4         5  magazin   Laptop      NaN   4715  14.01.2025

# %%
df["shop_date"] = df["shop_date"].fillna(method="ffill")
# Out:
# /tmp/ipykernel_20094/3275954875.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["shop_date"] = df["shop_date"].fillna(method="ffill")

# %%
df["product"]=df['product'].fillna(method="ffill")
# Out:
# /tmp/ipykernel_20094/1495375374.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["product"]=df['product'].fillna(method="ffill")

# %%
df["city"] = df["city"].fillna("namangan")
df.head()
# Out:
#    order_id     shop  product     city amount   shop_date
# 0         1   Shop B   Laptop  Bukhara   3950  16.01.2025
# 1         2   Shop E   Laptop  Bukhara   1393  16.01.2025
# 2         3  magazin  Monitor  Bukhara  1,200  17.09.2025
# 3         4  magazin  Monitor  Bukhara   2456  21.01.2025
# 4         5  magazin   Laptop  Bukhara   4715  14.01.2025

# %%
df.head()
# Out:
#    order_id     shop  product     city amount   shop_date
# 0         1   Shop B   Laptop  Bukhara   3950  16.01.2025
# 1         2   Shop E   Laptop  Bukhara   1393  16.01.2025
# 2         3  magazin  Monitor  Bukhara  1,200  17.09.2025
# 3         4  magazin  Monitor  Bukhara   2456  21.01.2025
# 4         5  magazin   Laptop  Bukhara   4715  14.01.2025
